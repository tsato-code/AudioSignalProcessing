# %%
# !pip install simpleaudio
# !pip install opencv-python
# !pip install plotly
import numpy as np
import matplotlib.pyplot as plt
import cis
import scipy.fftpack as sfft
import matplotlib.mlab as mlab
import scipy.signal as ss
# Out:
# Requirement already satisfied: simpleaudio in /anaconda/lib/python3.6/site-packages (1.0.2)
# Requirement already satisfied: opencv-python in /anaconda/lib/python3.6/site-packages (4.0.0.21)
# Requirement already satisfied: numpy>=1.11.3 in /anaconda/lib/python3.6/site-packages (from opencv-python) (1.15.0)
# Requirement already satisfied: plotly in /anaconda/lib/python3.6/site-packages (3.5.0)
# Requirement already satisfied: decorator>=4.0.6 in /anaconda/lib/python3.6/site-packages (from plotly) (4.3.0)
# Requirement already satisfied: nbformat>=4.2 in /anaconda/lib/python3.6/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: pytz in /anaconda/lib/python3.6/site-packages (from plotly) (2018.4)
# Requirement already satisfied: requests in /anaconda/lib/python3.6/site-packages (from plotly) (2.18.4)
# Requirement already satisfied: retrying>=1.3.3 in /anaconda/lib/python3.6/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /anaconda/lib/python3.6/site-packages (from plotly) (1.11.0)
# Requirement already satisfied: ipython_genutils in /anaconda/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /anaconda/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: jupyter_core in /anaconda/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda/lib/python3.6/site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda/lib/python3.6/site-packages (from requests->plotly) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda/lib/python3.6/site-packages (from requests->plotly) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/lib/python3.6/site-packages (from requests->plotly) (2018.11.29)
# /anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88

# %%
t = np.arange(0,1,1/8000)
a = 0.8
f = 440
y = a*np.sin(2*np.pi*f*t)

# %%
np.set_printoptions(precision=3)
y2 = np.sin(np.arange(0,1,0.01))

# %%
cis.audioplay(y,8000)

# %%
plt.figure()
plt.plot(t,y,'-')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
r = np.arange(2000,2200)
plt.figure()
plt.plot(t[r],y[r],'-')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
# 波形の重ね合わせ
fs = 8000
t = np.arange(0,1,1/fs)
a = 0.3
y523 = a*np.sin(2*np.pi*523*t)
y660 = a*np.sin(2*np.pi*660*t)
y784 = a*np.sin(2*np.pi*784*t)
yy = y523+y660+y784
cis.audioplay(yy,fs)
r = np.arange(200)
plt.figure()
plt.plot(t[r],yy[r])
plt.show()

# %%
a = 0.4
y438 = a*np.sin(2*np.pi*438*t)
y442 = a*np.sin(2*np.pi*442*t)
yy = y438+y442
cis.audioplay(yy,fs)
r = np.arange(200)
plt.figure()
plt.plot(t[r],yy[r])
plt.show()

# %%
# 連続再生
cis.audioplay(np.hstack((y523,y660)),fs)

# %%
v, fs = cis.wavread('audio/vibra8.wav')
t = np.arange(0,1,1/fs)
f = 440
a = 0.1
ysin = a*np.sin(2*np.pi*f*t)
# vmix = v+ysin
print(v.shape)
print(ysin.shape)
# Out:
# (26000,)
# (8000,)

# %%
vmix = v[7000:15000]+ysin
cis.audioplay(vmix,fs)
plt.figure()
plt.plot(vmix)
plt.show()

# %%
# 保存
cis.wavwrite('audio/mixed.wav',vmix,fs)

# %%
# FFT
fs = 100
t = np.arange(0,7,1/fs)
y = np.sin(2*np.pi*15*t)+np.cos(2*np.pi*40*t)
cs = sfft.fft(y[:600])
plt.figure()
plt.plot(y,'-')
#plt.plot(np.abs(cs),'--')
plt.show()

# %%
(np.abs(cs)>250).nonzero()
# Out:
# (array([ 90, 240, 360, 510]),)

# %%
print(cs[90])
print(cs[240])
# Out:
# (-7.972289495228324e-12-300.0000000000002j)
# (300.0000000000008-6.551204023708124e-12j)

# %%
np.angle(cs[np.array([90,240])])
# Out:
# array([-1.571e+00, -2.184e-14])

# %%
# フーリへ変換が問題になる例
plt.plot(np.abs(sfft.fft(y[0:599])))
plt.plot(np.abs(sfft.fft(y[0:601])),':')
plt.show()

# %%
# ハン窓
w = np.hanning(600)
plt.plot(w)
plt.show()

# %%
# ハン窓をかける
hy = y[:599]*np.hanning(599)
plt.plot(hy)
plt.show()
hcs = sfft.fft(hy)
plt.plot(np.abs(hcs))
lcs = sfft.fft(y[:599])
plt.plot(np.abs(lcs),':')
plt.show()

# %%
# フレーム処理
y,fs = cis.wavread('audio/domiso.wav')
plt.plot(np.abs(sfft.fft(y)))
plt.show()
cis.audioplay(y,fs)

# %%
plt.plot(np.abs(sfft.fft(y[1300:1812]*np.hanning(512))))
plt.show()

# %%
S,F,T = mlab.specgram(y,Fs=fs,NFFT=256,window=np.hanning(256),noverlap=128,mode='complex',sides='twosided')
S.shape
# Out:
# (256, 36)

# %%
_,_,_,_ = plt.specgram(y,Fs=fs,NFFT=256,window=np.hanning(256),noverlap=128)
_ = plt.xlabel('Time (s)')
_ = plt.ylabel('Frequency (Hz)')
plt.show()

# %%
plt.figure(1)
P,F,T,im = plt.specgram(y,Fs=fs,NFFT=256,window=np.hanning(256),noverlap=128)
plt.figure(2)
P,F,T,im = plt.specgram(y,Fs=fs,NFFT=512,window=np.hanning(512),noverlap=128)
plt.show()

# %%
# 逆フーリエ変換
S09 = S[:,9]
plt.plot(np.abs(S09))
plt.show()
plt.plot(np.real(sfft.ifft(sfft.fftshift(S09))))
plt.show()
